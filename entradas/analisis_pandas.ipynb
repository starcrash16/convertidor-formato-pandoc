# %% [markdown]
# # Análisis de Datos Financieros
#
# Este es un ejemplo de una celda de texto en Jupyter. El orquestador convertirá esto a texto normal en el Word.
#
# Podemos incluir listas:
# - Importación de datos
# - Limpieza
# - Visualización

# %%
import pandas as pd

# Creamos un DataFrame de ejemplo
data = {'Mes': ['Ene', 'Feb', 'Mar'], 'Ventas': [100, 120, 130]}
df = pd.DataFrame(data)

print(df)
# Out:
#    Mes  Ventas
# 0  Ene     100
# 1  Feb     120
# 2  Mar     130

# %% [markdown]
# ### Conclusión del Script
# El código anterior será renderizado dentro de un bloque de código en el Word final, mientras que este texto mantendrá el formato de lectura.
